# %% [markdown]
# <a href="https://colab.research.google.com/github/Nguyh3/HannaN/blob/main/project-data-question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment Directions
#
# In a code cell below this one, pull your data into a dataframe.
#
# In a markdown cell, the student should explain the dataset they have chosen and the question they are trying to answer. Why do you think this dataset is interesting? What do you hope to learn from it? What are your goals?

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data/CO2 Emissions_Canada.csv")
df
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
# ...

# %% [markdown]
# Based on the data I chose, I want to answer the question of what features of a vehicle affect the CO2 emissions the most?
#
# This dataset is interesting to me because I'd like to have a better understanding on how emissions have an impact on our climate, especially how our world is being impacted by climate change.
#
# I hope to learn about the different variations of vehicle features since I don't have any background knowledge on them. Overall, I want to have a deeper understanding on environmental impacts because I see it as a valuable lesson to learn from.
